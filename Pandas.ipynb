# %% [markdown]
# <a href="https://colab.research.google.com/github/JuarezEmmanuel/Data-Science-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas y Manipulación de DataFrames
#
# **Juarez Emmanuel**
#
# **Objetivos**
#
# Manipular conjuntos de datos usando Pandas para la exploración y preparación de datos en análisis. En esta sesión aprenderán a cargar datos, crear DataFrames, manipular sus columnas y realizar operaciones básicas sobre los datos utilizando el dataset de venta_llantas.xlsx
#
# **Temario**
#
# * ¿Qué es Pandas?
# * Carga de datos
# * Creación y manipulación de DataFrames
# * Operaciones Básicas con Pandas
# * Guardado y Exportación de Datos
#
# **Logros de la Clase**
#
#
# * Carga de un archivo Excel en un DataFrame.
# * Realizar una exploración básica de los datos utilizando las funciones más comunes de Pandas.
# * Seleccionar y modificar columnas y filas dentro de un DataFrame.
# * Filtrar datos según condiciones específicas.
# * Guarde un DataFrame modificado en un nuevo archivo Excel para futuras manipulaciones.

# %% [markdown]
# ## ¿Qué es Pandas?
# Pandas es una biblioteca fundamental en Python diseñada específicamente para el manejo y análisis de datos estructurados, como tablas o series de tiempo. Su nombre proviene de "Panel Data", una estructura de datos que es muy común en análisis económicos, pero su uso se ha extendido a todo tipo de análisis de datos en múltiples áreas como la ciencia de datos, estadísticas, investigación y desarrollo, entre otros.
#
# ¿Por qué Pandas es clave para el análisis de datos?
# * Facilidad de uso: Pandas proporciona estructuras de datos de alto nivel que son fáciles de manipular y analizar. Las operaciones comunes como filtrar, agrupar o transformar datos son más sencillas comparadas con hacerlo directamente en Python puro.
# * Velocidad y eficiencia: Pandas está optimizado para realizar operaciones sobre grandes conjuntos de datos de manera eficiente.
# * Integración con otras bibliotecas: Pandas funciona bien con otras bibliotecas importantes como NumPy, Matplotlib y Scikit-learn, lo que hace que sea muy útil en el flujo de trabajo de un científico de datos.
# * Soporte para datos diversos: Pandas puede manejar diferentes tipos de datos, como CSV, Excel, SQL y más, facilitando la importación y exportación de datos en diferentes formatos.
#
# **Conceptos Clave: Series y DataFrames**
#
# * Serie: es una estructura de datos unidimensional, similar a una lista o un array de NumPy, pero con algunas características adicionales. Cada elemento en una Serie tiene una etiqueta o índice, lo que permite un acceso más eficiente a los datos. Piensa en una Serie como una columna de datos de una tabla.

# %%
import pandas as pd

# %%
# Ejemplo de serie

serie = pd.Series([10, 20, 30, 40, 80])
print(serie)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    80
# dtype: int64

# %% [markdown]
# * DataFrame:
#
# Es la estructura de datos bidimensional más utilizada en Pandas. Es similar a una tabla de una hoja de cálculo o una base de datos, donde cada columna es una Serie y puede tener un tipo de dato diferente. Los DataFrames son extremadamente flexibles y nos permiten realizar operaciones como filtrar datos, agregar columnas, unir tablas, etc.

# %%
# Ejemplo de DataFrame

data = {'Nombre': ['Ana', 'Luiz', 'Carlos'], 'Edad': [28, 35, 19]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Nombre  Edad
# 0     Ana    28
# 1    Luiz    35
# 2  Carlos    19

# %%
df
# Out:
#    Nombre  Edad
# 0     Ana    28
# 1    Luiz    35
# 2  Carlos    19

# %% [markdown]
# **Importancia de Pandas en el Análisis de Datos**
#
# Pandas es esencial para el análisis de datos porque proporciona:
#
# * Limpieza de Datos : La mayoría de los datos que usamos en la vida real no están en un formato limpio. Pandas permite realizar operaciones como manejar valores nulos, transformar tipos de datos, o modificar estructuras de tablas con gran facilidad.
#
# * Manipulación de Datos : A menudo, necesitamos transformar o agregar información a nuestros datos. Con Pandas, podemos realizar tareas como:
#   * Filtrar filas o columnas.
#   * Aplicar funciones sobre grupos de datos.
#   * Fusionar, concatenar o pivotar tablas.
#
# * Análisis Exploratorio de Datos (EDA) : Antes de aplicar un modelo de Machine Learning o cualquier otra técnica avanzada, es fundamental entender los datos. Pandas facilita calcular estadísticas descriptivas, generar resúmenes y crear subconjuntos de datos relevantes para profundizar en el análisis.
#
# **Conclusión**
# En resumen, Pandas es una de las bibliotecas más poderosas y versátiles para el análisis de datos en Python. Desde la limpieza hasta el análisis profundo, Pandas ofrece herramientas que optimizan cada etapa del proceso de trabajo con datos. Durante este curso, profundizaremos en cómo manipular y explorar datos utilizando esta biblioteca, lo que es crucial para todo análisis de datos eficiente.

# %%
# !pip install -U gdown
# !gdown 1kFa35DYNnfLzAAMEwE7pGwa0RiZN48_n  #Carga desde enlace de drive

import pandas as pd

df = pd.read_excel('venta_llantas.xlsx')
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1kFa35DYNnfLzAAMEwE7pGwa0RiZN48_n
# To: /content/venta_llantas.xlsx
# 100% 10.7M/10.7M [00:00<00:00, 161MB/s]

# %%
# Mostrar las primeras 10 filas del DataFrame
df.head(10)
# Out:
#      IdCliente             NombreCliente      Fecha  Empleado   Referencia  \
# 0  C1070956433                PINTO JOHN 2016-09-01      24.0   LL-2R-0038
# 1  C1032372566                CESAR CRUZ 2016-09-01      14.0  LL-TCA-0133
# 2     C2865810              PINEDA JAIME 2016-09-01      12.0  LL-TCA-0019
# 3    C11210285  VILLALBA RODRIGUEZ FABIO 2016-09-01      24.0  LL-TCA-0009
# 4    C80755314             MOLINA RONALD 2016-09-01      14.0  LL-TCA-0132
# 5    C21111935          URQUIJO MERCEDES 2016-09-01      14.0  LL-TCA-0022
# 6    C79295843           GOMEZ FRANCISCO 2016-09-01      12.0  LL-TCA-0100
# 7    C79827395             BALLEN CARLOS 2016-09-01      24.0  LL-PLB-0013
# 8   C860002175  SCHLUMBERGER SURENCO S A 2016-09-01       7.0  LL-TCC-0020
# 9    C19091837             URIBE GABRIEL 2016-09-01      12.0  LL-TCA-0114
#
#                                       Descripcion  CodigoFamilia Familia  \
# 0                          PILOT STREET 110/80-17          101.0  LLANTA
# 1                               TOURING 175/70R13          101.0  LLANTA
# 2                            ENERGY XM2 185/65R14          101.0  LLANTA
# 3                            ENERGY XM2 165/65R13          101.0  LLANTA
# 4                                     NO UTILIZAR          101.0  LLANTA
# 5                            ENERGY XM2 185/70R14          101.0  LLANTA
# 6                          PRIMACY 3 ZP 205/55R16          101.0  LLANTA
# 7  ST250 215/75R17.5 NO UTILIZAR REEM LL-PLB-0040          101.0  LLANTA
# 8                   ALL TERRAIN T/A KO2 265/70R16          101.0  LLANTA
# 9                             PRIMACY 3 205/60R16          101.0  LLANTA
#
#    Cantidad     Ventas      Localidad             Sede  Area
# 0       1.0   129310.0  Puente aranda         Calle 13  35.0
# 1       2.0   181034.0           Suba             Suba  32.0
# 2       1.0   193095.0        Usaquen        Santa ana  33.0
# 3       2.0   262069.0  Puente aranda         Calle 13  35.0
# 4       4.0   362069.0           Suba             Suba  32.0
# 5       4.0   720690.0           Suba             Suba  32.0
# 6       2.0   737931.0        Usaquen        Santa ana  33.0
# 7       2.0   931034.0  Puente aranda         Calle 13  35.0
# 8       2.0   950015.0       Engativa  Ventas externas  22.0
# 9       4.0  1167069.0        Usaquen        Santa ana  33.0

# %%
# Muestra la informacion Basica del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127266 entries, 0 to 127265
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   IdCliente      127255 non-null  object
#  1   NombreCliente  127255 non-null  object
#  2   Fecha          127255 non-null  datetime64[ns]
#  3   Empleado       127255 non-null  float64
#  4   Referencia     127255 non-null  object
#  5   Descripcion    127255 non-null  object
#  6   CodigoFamilia  127255 non-null  float64
#  7   Familia        127255 non-null  object
#  8   Cantidad       127255 non-null  float64
#  9   Ventas         127255 non-null  float64
#  10  Localidad      127255 non-null  object
#  11  Sede           127256 non-null  object
#  12  Area           127255 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 12.6+ MB

# %%
# Muestra las estadisticas descriptivas de las columnas numericas
df.describe()
# Out:
#                                Fecha       Empleado  CodigoFamilia  \
# count                         127255  127255.000000  127255.000000
# mean   2018-06-10 09:10:03.842678016      24.992260     105.224730
# min              2016-09-01 00:00:00       1.000000     101.000000
# 25%              2017-07-28 00:00:00      10.000000     106.000000
# 50%              2018-06-07 00:00:00      14.000000     106.000000
# 75%              2019-05-04 00:00:00      44.000000     106.000000
# max              2020-03-10 00:00:00      68.000000     109.000000
# std                              NaN      18.593875       2.201746
#
#             Cantidad        Ventas           Area
# count  127255.000000  1.272550e+05  127255.000000
# mean        2.475872  5.848578e+05      30.180747
# min         1.000000  1.300000e+02      21.000000
# 25%         1.000000  1.260500e+04      31.000000
# 50%         1.000000  2.941200e+04      31.000000
# 75%         2.000000  5.172400e+04      33.000000
# max       971.000000  2.202246e+08      35.000000
# std        11.206424  3.251382e+06       4.355697

# %%
# Seleccionar una columna por Nombre
ventas = df['Ventas']
ventas.head(5)
# Out:
# 0    129310.0
# 1    181034.0
# 2    193095.0
# 3    262069.0
# 4    362069.0
# Name: Ventas, dtype: float64

# %%
# Seleccionar varias columnas
subset = df[['IdCliente', 'Ventas', 'Cantidad']]
subset.head(15)
# Out:
#       IdCliente     Ventas  Cantidad
# 0   C1070956433   129310.0       1.0
# 1   C1032372566   181034.0       2.0
# 2      C2865810   193095.0       1.0
# 3     C11210285   262069.0       2.0
# 4     C80755314   362069.0       4.0
# 5     C21111935   720690.0       4.0
# 6     C79295843   737931.0       2.0
# 7     C79827395   931034.0       2.0
# 8    C860002175   950015.0       2.0
# 9     C19091837  1167069.0       4.0
# 10   C800035276  1324483.0       1.0
# 11   C900069712  1324483.0       1.0
# 12   C900069712  1429173.0       2.0
# 13   C900069712  1668690.0       2.0
# 14   C900280249  2034483.0       4.0

# %%
# Seleccionar filas con .iloc  ( por indice)

df.iloc[10:14]
# Out:
#      IdCliente            NombreCliente      Fecha  Empleado   Referencia  \
# 10  C800035276  TRANSPORTES MONTEJO SAS 2016-09-01       2.0  LL-PLC-0074
# 11  C900069712    MONTEJO HEAVY LIFT SA 2016-09-01       2.0  LL-PLC-0074
# 12  C900069712    MONTEJO HEAVY LIFT SA 2016-09-01       2.0  LL-PLC-0083
# 13  C900069712    MONTEJO HEAVY LIFT SA 2016-09-01       2.0  LL-PLC-0084
#
#               Descripcion  CodigoFamilia Familia  Cantidad     Ventas  \
# 10  X MULTI Z 295/80R22.5          101.0  LLANTA       1.0  1324483.0
# 11  X MULTI Z 295/80R22.5          101.0  LLANTA       1.0  1324483.0
# 12       XTE2 215/75R17.5          101.0  LLANTA       2.0  1429173.0
# 13       XTE2 235/75R17.5          101.0  LLANTA       2.0  1668690.0
#
#    Localidad             Sede  Area
# 10  Engativa  Ventas externas  22.0
# 11  Engativa  Ventas externas  22.0
# 12  Engativa  Ventas externas  22.0
# 13  Engativa  Ventas externas  22.0

# %%
df.iloc[10:11]
# Out:
#      IdCliente            NombreCliente      Fecha  Empleado   Referencia  \
# 10  C800035276  TRANSPORTES MONTEJO SAS 2016-09-01       2.0  LL-PLC-0074
#
#               Descripcion  CodigoFamilia Familia  Cantidad     Ventas  \
# 10  X MULTI Z 295/80R22.5          101.0  LLANTA       1.0  1324483.0
#
#    Localidad             Sede  Area
# 10  Engativa  Ventas externas  22.0

# %%
# Seleccionar Filas por etiquetas con .loc

df.loc[df['Sede'] == 'Calle 80']
# Out:
#           IdCliente                   NombreCliente      Fecha  Empleado  \
# 17       C890300225                     COEXITO SAS 2016-09-01      10.0
# 33        C19193625                   GEBARA NESTOR 2016-09-02      10.0
# 35        C60346740                 COLMENARES LUCY 2016-09-01      10.0
# 40       C860524195           TRANSPORTES RINCON SA 2016-09-01      10.0
# 41        C79203647                  RAMIREZ CARLOS 2016-09-01      21.0
# ...             ...                             ...        ...       ...
# 127225    C79526865                    CAMELO DUVAN 2020-03-10      44.0
# 127226    C79547553                 JIMENEZ EDUARDO 2020-03-10      44.0
# 127229  C2032386257  OLATE GONZALEZ JONATHAN IRALDO 2020-03-10      44.0
# 127230    C51907365               BERNAL VACA NINFA 2020-03-10      44.0
# 127241    C19210389          VILLAREAL HECTOR JULIO 2020-03-10      66.0
#
#            Referencia                                   Descripcion  \
# 17       SE-CS-2-0003                               BALANCEO CAMION
# 33        LL-TCA-0020                          ENERGY XM2 185/65R15
# 35      SE-CS-10-0001                     CALIBRACION CON NITROGENO
# 40       SE-CS-4-0001  REPARACION MENOR DE LLANTA (DESPINCHE ) TACO
# 41       SE-GF-4-0001                  REPARACION MENOR (DESPINCHE)
# ...               ...                                           ...
# 127225  SE-CS-12-0011                MANO OBRA CAMBIO LIQUIDO FRENO
# 127226  SE-CS-12-0011                MANO OBRA CAMBIO LIQUIDO FRENO
# 127229   SE-CS-1-0005            ALINEACION BUSETA O CAMION LIVIANO
# 127230   SE-CS-1-0002                          ALINEACION CAMIONETA
# 127241    LL-TCA-0133                             TOURING 175/70R13
#
#         CodigoFamilia    Familia  Cantidad    Ventas Localidad      Sede  Area
# 17              106.0  SERVICIOS       1.0    2069.0  Engativa  Calle 80  31.0
# 33              101.0     LLANTA       1.0  216379.0  Engativa  Calle 80  31.0
# 35              106.0  SERVICIOS       1.0    5000.0  Engativa  Calle 80  31.0
# 40              106.0  SERVICIOS       1.0   10345.0  Engativa  Calle 80  31.0
# 41              106.0  SERVICIOS       1.0   12931.0  Engativa  Calle 80  31.0
# ...               ...        ...       ...       ...       ...       ...   ...
# 127225          106.0  SERVICIOS       1.0   37815.0  Engativa  Calle 80  31.0
# 127226          106.0  SERVICIOS       1.0   37815.0  Engativa  Calle 80  31.0
# 127229          106.0  SERVICIOS       1.0   42017.0  Engativa  Calle 80  31.0
# 127230          106.0  SERVICIOS       1.0   42017.0  Engativa  Calle 80  31.0
# 127241          101.0     LLANTA       1.0  133916.0  Engativa  Calle 80  31.0
#
# [53052 rows x 13 columns]

# %%
df.loc[(df['IdCliente'] == 'C2865810') & (df['Cantidad'] >=2)]
# Out:
#       IdCliente NombreCliente      Fecha  Empleado   Referencia  \
# 32964  C2865810  PINEDA JAIME 2017-08-09      12.0  LL-TCA-0019
#
#                 Descripcion  CodigoFamilia Familia  Cantidad    Ventas  \
# 32964  ENERGY XM2 185/65R14          101.0  LLANTA       2.0  381177.0
#
#       Localidad       Sede  Area
# 32964   Usaquen  Santa ana  33.0

# %%
df.loc[(df['Sede'] == 'Suba') | (df['Familia'] == 'LLANTA')]
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1       C1032372566                                         CESAR CRUZ
# 2          C2865810                                       PINEDA JAIME
# 3         C11210285                           VILLALBA RODRIGUEZ FABIO
# 4         C80755314                                      MOLINA RONALD
# ...             ...                                                ...
# 127250   C891100881                     MORENO VARGAS SOCIEDAD ANONIMA
# 127251   C900364615                              ORGANIZACION SUMA SAS
# 127252   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127253   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127254   C900364615                              ORGANIZACION SUMA SAS
#
#             Fecha  Empleado   Referencia             Descripcion  \
# 0      2016-09-01      24.0   LL-2R-0038  PILOT STREET 110/80-17
# 1      2016-09-01      14.0  LL-TCA-0133       TOURING 175/70R13
# 2      2016-09-01      12.0  LL-TCA-0019    ENERGY XM2 185/65R14
# 3      2016-09-01      24.0  LL-TCA-0009    ENERGY XM2 165/65R13
# 4      2016-09-01      14.0  LL-TCA-0132             NO UTILIZAR
# ...           ...       ...          ...                     ...
# 127250 2020-03-10       2.0  LL-PLC-0159  X WORKS HD XDY 12R22.5
# 127251 2020-03-10       1.0  LL-PLB-0024   X MULTI Z 235/75R17.5
# 127252 2020-03-10       2.0  LL-PLB-0024   X MULTI Z 235/75R17.5
# 127253 2020-03-10       2.0  LL-PLB-0031       XZE2 215/75 R17.5
# 127254 2020-03-10       1.0  LL-PLC-0074   X MULTI Z 295/80R22.5
#
#         CodigoFamilia Familia  Cantidad      Ventas      Localidad  \
# 0               101.0  LLANTA       1.0    129310.0  Puente aranda
# 1               101.0  LLANTA       2.0    181034.0           Suba
# 2               101.0  LLANTA       1.0    193095.0        Usaquen
# 3               101.0  LLANTA       2.0    262069.0  Puente aranda
# 4               101.0  LLANTA       4.0    362069.0           Suba
# ...               ...     ...       ...         ...            ...
# 127250          101.0  LLANTA       4.0   5635766.0       Engativa
# 127251          101.0  LLANTA       9.0   6894000.0       Engativa
# 127252          101.0  LLANTA      20.0  11955636.0       Engativa
# 127253          101.0  LLANTA      30.0  15908063.0       Engativa
# 127254          101.0  LLANTA      14.0  21868000.0       Engativa
#
#                    Sede  Area
# 0              Calle 13  35.0
# 1                  Suba  32.0
# 2             Santa ana  33.0
# 3              Calle 13  35.0
# 4                  Suba  32.0
# ...                 ...   ...
# 127250  Ventas externas  22.0
# 127251  Ventas externas  22.0
# 127252  Ventas externas  22.0
# 127253  Ventas externas  22.0
# 127254  Ventas externas  22.0
#
# [34001 rows x 13 columns]

# %%
# Seleccionar las filas con cantidad mayor o igual a 5
df['Cantidad'] >=5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 127261    False
# 127262    False
# 127263    False
# 127264    False
# 127265    False
# Name: Cantidad, Length: 127266, dtype: bool

# %%
#Seleccione las columnas "Area" y "Ventas", luego muestre las primeras 10 filas.
sub = df[['Area', 'Ventas']]
sub.head(10)
# Out:
#    Area     Ventas
# 0  35.0   129310.0
# 1  32.0   181034.0
# 2  33.0   193095.0
# 3  35.0   262069.0
# 4  32.0   362069.0
# 5  32.0   720690.0
# 6  33.0   737931.0
# 7  35.0   931034.0
# 8  22.0   950015.0
# 9  33.0  1167069.0

# %%
# Seleccionar las filas con area entre 30 y 34

df.loc[(df['Area'] == 30) | (df['Area'] == 34)]
# Out:
#           IdCliente        NombreCliente      Fecha  Empleado    Referencia  \
# 37        C39639383      JINENEZ PARICIA 2016-09-01      28.0  SE-CS-2-0001
# 38      C1073599317           NEME JAIRO 2016-09-01      28.0  SE-CS-2-0002
# 47         C7333956         AVILA JENNER 2016-09-01      28.0  SE-CS-2-0002
# 78      C1073599317           NEME JAIRO 2016-09-01      28.0  SE-CS-1-0002
# 79         C7333956         AVILA JENNER 2016-09-01      28.0  SE-CS-1-0002
# ...             ...                  ...        ...       ...           ...
# 127073  C1022357586  RODRIGUEZ SEBASTIAN 2020-03-09      45.0  SE-CS-4-0001
# 127149  C1022357586  RODRIGUEZ SEBASTIAN 2020-03-09      45.0  SE-CS-9-0003
# 127218    C87063750          CASTRO JOHN 2020-03-10      45.0  SE-CS-2-0001
# 127243     C3496753         ALAYON FABIO 2020-03-10      45.0   LL-TCU-0011
# 127247    C87063750          CASTRO JOHN 2020-03-10      45.0   LL-TCA-0508
#
#                                          Descripcion  CodigoFamilia  \
# 37                                     BALANCEO AUTO          106.0
# 38                                BALANCEO CAMIONETA          106.0
# 47                                BALANCEO CAMIONETA          106.0
# 78                              ALINEACION CAMIONETA          106.0
# 79                              ALINEACION CAMIONETA          106.0
# ...                                              ...            ...
# 127073  REPARACION MENOR DE LLANTA (DESPINCHE ) TACO          106.0
# 127149   COMBO ALINE-BALAN-CALIB CON NITRO E INSPECC          106.0
# 127218                                 BALANCEO AUTO          106.0
# 127243                            AGILIS R 195/75R16          101.0
# 127247                    PRIMACY 4 MI 225/55R16 99W          101.0
#
#           Familia  Cantidad     Ventas       Localidad      Sede  Area
# 37      SERVICIOS       2.0     8621.0  Barrios unidos  Av Chile  34.0
# 38      SERVICIOS       2.0     8621.0  Barrios unidos  Av Chile  34.0
# 47      SERVICIOS       4.0    17241.0  Barrios unidos  Av Chile  34.0
# 78      SERVICIOS       1.0    25862.0  Barrios unidos  Av Chile  34.0
# 79      SERVICIOS       1.0    25862.0  Barrios unidos  Av Chile  34.0
# ...           ...       ...        ...             ...       ...   ...
# 127073  SERVICIOS       1.0    10084.0  Barrios unidos  Av Chile  34.0
# 127149  SERVICIOS       1.0    58824.0  Barrios unidos  Av Chile  34.0
# 127218  SERVICIOS       4.0    33613.0  Barrios unidos  Av Chile  34.0
# 127243     LLANTA       2.0   800000.0  Barrios unidos  Av Chile  34.0
# 127247     LLANTA       3.0  1438412.0  Barrios unidos  Av Chile  34.0
#
# [12104 rows x 13 columns]

# %%
# Crear una nueva columna con el total de venta
# cantidad * venta

df['TotalVentas'] = df['Cantidad'] * df['Ventas']
df.head()
# Out:
#      IdCliente             NombreCliente      Fecha  Empleado   Referencia  \
# 0  C1070956433                PINTO JOHN 2016-09-01      24.0   LL-2R-0038
# 1  C1032372566                CESAR CRUZ 2016-09-01      14.0  LL-TCA-0133
# 2     C2865810              PINEDA JAIME 2016-09-01      12.0  LL-TCA-0019
# 3    C11210285  VILLALBA RODRIGUEZ FABIO 2016-09-01      24.0  LL-TCA-0009
# 4    C80755314             MOLINA RONALD 2016-09-01      14.0  LL-TCA-0132
#
#               Descripcion  CodigoFamilia Familia  Cantidad    Ventas  \
# 0  PILOT STREET 110/80-17          101.0  LLANTA       1.0  129310.0
# 1       TOURING 175/70R13          101.0  LLANTA       2.0  181034.0
# 2    ENERGY XM2 185/65R14          101.0  LLANTA       1.0  193095.0
# 3    ENERGY XM2 165/65R13          101.0  LLANTA       2.0  262069.0
# 4             NO UTILIZAR          101.0  LLANTA       4.0  362069.0
#
#        Localidad       Sede  Area  TotalVentas
# 0  Puente aranda   Calle 13  35.0     129310.0
# 1           Suba       Suba  32.0     362068.0
# 2        Usaquen  Santa ana  33.0     193095.0
# 3  Puente aranda   Calle 13  35.0     524138.0
# 4           Suba       Suba  32.0    1448276.0

# %%
# Modificar los valores de una columna existente

df['Cantidad'] = df['Cantidad'] * 2
df.head()
# Out:
#      IdCliente             NombreCliente      Fecha  Empleado   Referencia  \
# 0  C1070956433                PINTO JOHN 2016-09-01      24.0   LL-2R-0038
# 1  C1032372566                CESAR CRUZ 2016-09-01      14.0  LL-TCA-0133
# 2     C2865810              PINEDA JAIME 2016-09-01      12.0  LL-TCA-0019
# 3    C11210285  VILLALBA RODRIGUEZ FABIO 2016-09-01      24.0  LL-TCA-0009
# 4    C80755314             MOLINA RONALD 2016-09-01      14.0  LL-TCA-0132
#
#               Descripcion  CodigoFamilia Familia  Cantidad    Ventas  \
# 0  PILOT STREET 110/80-17          101.0  LLANTA       2.0  129310.0
# 1       TOURING 175/70R13          101.0  LLANTA       4.0  181034.0
# 2    ENERGY XM2 185/65R14          101.0  LLANTA       2.0  193095.0
# 3    ENERGY XM2 165/65R13          101.0  LLANTA       4.0  262069.0
# 4             NO UTILIZAR          101.0  LLANTA       8.0  362069.0
#
#        Localidad       Sede  Area  TotalVentas
# 0  Puente aranda   Calle 13  35.0     129310.0
# 1           Suba       Suba  32.0     362068.0
# 2        Usaquen  Santa ana  33.0     193095.0
# 3  Puente aranda   Calle 13  35.0     524138.0
# 4           Suba       Suba  32.0    1448276.0

# %% [markdown]
# # Filtrado de datos Usando condiciones

# %%
# Filtrar las filas donde las ventas sean mayores a 100,000

ventas_altas = df.loc[df['Ventas'] > 100000]
ventas_altas.head()
# Out:
#      IdCliente             NombreCliente      Fecha  Empleado   Referencia  \
# 0  C1070956433                PINTO JOHN 2016-09-01      24.0   LL-2R-0038
# 1  C1032372566                CESAR CRUZ 2016-09-01      14.0  LL-TCA-0133
# 2     C2865810              PINEDA JAIME 2016-09-01      12.0  LL-TCA-0019
# 3    C11210285  VILLALBA RODRIGUEZ FABIO 2016-09-01      24.0  LL-TCA-0009
# 4    C80755314             MOLINA RONALD 2016-09-01      14.0  LL-TCA-0132
#
#               Descripcion  CodigoFamilia Familia  Cantidad    Ventas  \
# 0  PILOT STREET 110/80-17          101.0  LLANTA       2.0  129310.0
# 1       TOURING 175/70R13          101.0  LLANTA       4.0  181034.0
# 2    ENERGY XM2 185/65R14          101.0  LLANTA       2.0  193095.0
# 3    ENERGY XM2 165/65R13          101.0  LLANTA       4.0  262069.0
# 4             NO UTILIZAR          101.0  LLANTA       8.0  362069.0
#
#        Localidad       Sede  Area  TotalVentas
# 0  Puente aranda   Calle 13  35.0     129310.0
# 1           Suba       Suba  32.0     362068.0
# 2        Usaquen  Santa ana  33.0     193095.0
# 3  Puente aranda   Calle 13  35.0     524138.0
# 4           Suba       Suba  32.0    1448276.0

# %%
# Filtrar las sedes

sedes_suba = df.loc[df['Sede'] == 'Suba']
sedes_suba.head()
# Out:
#       IdCliente     NombreCliente      Fecha  Empleado    Referencia  \
# 1   C1032372566        CESAR CRUZ 2016-09-01      14.0   LL-TCA-0133
# 4     C80755314     MOLINA RONALD 2016-09-01      14.0   LL-TCA-0132
# 5     C21111935  URQUIJO MERCEDES 2016-09-01      14.0   LL-TCA-0022
# 15    C41712753     DIAZ LUZ MARY 2016-09-01      14.0  SE-CS-8-0001
# 34    C52206114    HERNANDEZ ALBA 2016-09-01      14.0  SE-CS-8-0001
#
#              Descripcion  CodigoFamilia    Familia  Cantidad    Ventas  \
# 1      TOURING 175/70R13          101.0     LLANTA       4.0  181034.0
# 4            NO UTILIZAR          101.0     LLANTA       8.0  362069.0
# 5   ENERGY XM2 185/70R14          101.0     LLANTA       8.0  720690.0
# 15      CAMBIO DE ACEITE          106.0  SERVICIOS       2.0     862.0
# 34      CAMBIO DE ACEITE          106.0  SERVICIOS       2.0    2586.0
#
#    Localidad  Sede  Area  TotalVentas
# 1       Suba  Suba  32.0     362068.0
# 4       Suba  Suba  32.0    1448276.0
# 5       Suba  Suba  32.0    2882760.0
# 15      Suba  Suba  32.0        862.0
# 34      Suba  Suba  32.0       2586.0

# %% [markdown]
# # Guardado de un DataFrame a un nuevo archivo Excel

# %%
sedes_suba.to_excel('Modificado.xlsx', index=False)

# Archivo en la carpeta temporar de drive
