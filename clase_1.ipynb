# %% [markdown]
# # Primera parte: Explicación introductoria
#
# # ¿Qué es Python y sus plataformas de trabajo? 🐍
#
# Python es un lenguaje de programación de alto nivel que se utiliza ampliamente en diversas áreas, como desarrollo web, análisis de datos, inteligencia artificial y más. Existen varias plataformas de trabajo para Python, entre las cuales se destacan:
#
# - **Entornos de desarrollo integrado (IDE)**: como PyCharm, VSCode, y Jupyter Notebook.
# - **Plataformas en la nube**: como Google Colab, que permite ejecutar código Python en la nube de manera colaborativa.
# - **Intérpretes de Python**: como CPython, el intérprete estándar de Python.
#
# # ¿Qué es Google Colab y cómo es su estructura? 🖥️
#
# Google Colab es una plataforma en la nube que ofrece un entorno de ejecución gratuito para Python. Permite escribir y ejecutar código Python en el navegador web, facilitando la colaboración y el acceso a recursos computacionales poderosos, como GPU y TPU.
#
# La estructura básica de un notebook de Google Colab se compone de celdas, que pueden contener tanto código como texto en formato Markdown. Puedes agregar nuevas celdas utilizando los botones "+" en la parte superior o con el atajo de teclado Ctrl+M B. Además, Google Colab ofrece diversas opciones de configuración, como la selección del entorno de ejecución y la instalación de paquetes adicionales.
#
# # Variables, constantes y operadores en Python 🎨
#
# En Python, una variable es un contenedor que almacena datos y puede cambiar de valor durante la ejecución del programa. Por otro lado, una constante es un valor fijo que no cambia a lo largo del programa. Python no tiene punteros como en otros lenguajes de programación, ya que maneja la memoria de manera automática.
#
# Los operadores en Python se utilizan para realizar operaciones sobre variables y valores. Entre los operadores matemáticos y lógicos más comunes se encuentran:
#
# - **Operadores matemáticos**: `+` (suma), `-` (resta), `*` (multiplicación), `/` (división), `%` (módulo), `**` (exponente).
# - **Operadores lógicos**: `and` (y), `or` (o), `not` (no), `==` (igual), `!=` (no igual), `>` (mayor que), `<` (menor que), `>=` (mayor o igual que), `<=` (menor o igual que).
#
# Ahora, pasemos a los ejercicios:

# %% [markdown]
# Ejercicio 1: ¡Hola, para nuestra clase! 👋
# Escribe un programa que imprima "Hola, Mundo" en la pantalla.

# %%
print ("hola IDSA")
# Out:
# hola IDSA

# %% [markdown]
# Ejercicio 2: Variables en Python 📦

# %%
edad = 25
edad
# Out:
# 25

# %% [markdown]
# Ejercicio 3: Constantes en Python 🏰

# %%
PI = 3.14159
PI
# Out:
# 3.14159

# %% [markdown]
# Ejercicio 4: copia de data Python 🔍

# %%
T_edad = edad #aca se puede escribir un comentario
T_edad
# Out:
# 25

# %% [markdown]
# Ejercicio 5: Vemos los tipos de varibles 🔍?

# %%
# Verificar el tipo de las variables
tipo_numero_entero = type(T_edad)
tipo_numero_flotante = type(PI)

# Imprimir el tipo de las variables
print("El tipo de la variable es:", tipo_numero_entero)
print("El tipo de la variable es:", tipo_numero_flotante)
# Out:
# El tipo de la variable es: <class 'int'>
# El tipo de la variable es: <class 'float'>

# %% [markdown]
# Ejercicio 6: Operadores matemáticos básicos 🧮
# Escribe un programa que calcule la suma de dos números enteros.

# %%
num1 = 10
num2 = 5
suma = num1 + num2
print("La suma de los números es:", suma)
# Out:
# La suma de los números es: 15

# %% [markdown]
# Ejercicio 6: Operadores matemáticos básicos 🧮
# Escribe un programa que calcule la resta de dos números enteros.

# %%
num1 = 10
num2 = 5
resta = num1 - num2
print("La resta de los números es:", resta)
# Out:
# La resta de los números es: 5

# %% [markdown]
# Ejercicio 8:
# Escribe un programa que calcule el producto de dos números enteros.🔢

# %%
producto = num1 * num2
print("El producto de los números es:", producto)
# Out:
# El producto de los números es: 50

# %% [markdown]
# Ejercicio 9: Operadores matemáticos y lógicos en Python 🧠

# %%
#area del rectangulo
base = 5
altura = 3
area = base * altura
print("El área del rectángulo es:", area)
# Out:
# El área del rectángulo es: 15

# %% [markdown]
# Ejercicio 10: Aplicación del operador módulo (%)
#
# Supongamos que queremos calcular el resto de la división de un número por otro.
# Utilizaremos el operador módulo (%) para obtener este resto.

# %%
# Definimos dos números para la división
dividendo = 10
divisor = 3

# Calculamos el resto de la división
resto = dividendo % divisor

# Imprimimos el resultado
print("El resto de la división de", dividendo, "modulo", divisor, "es:", resto)
# Out:
# El resto de la división de 10 modulo 3 es: 1

# %% [markdown]
# Ejercicio 11: Operadores lógicos ♈

# %%
# Definimos dos variables booleanas
verdadero = True
falso = False

# %% [markdown]
# Ejercicio 12: Verificamos resultados ♈

# %%
# Verificamos si ambas variables son verdaderas
resultado_conjuncion = verdadero and falso
print("Conjunción entre verdadero y falso:", resultado_conjuncion)
# Out:
# Conjunción entre verdadero y falso: False

# %% [markdown]
# Ejercicio 13: Verificamos resultados ♈

# %%
# Verificamos si al menos una de las variables es verdadera
resultado_disyuncion = verdadero or falso
print("Disyunción entre verdadero y falso:", resultado_disyuncion)
# Out:
# Disyunción entre verdadero y falso: True

# %% [markdown]
# Ejercicio 14: Verificamos resultados con NOT ♈

# %%
# Negamos el valor de la variable verdadero
Negación = not verdadero
print("Negación de verdadero:", Negación)
# Out:
# Negación de verdadero: False

# %% [markdown]
# Ejercicio 15: Verificamos resultados combinados ♈

# %%
# Aplicamos una combinación de operadores lógicos
resultado_combinado = (verdadero and not falso) or (falso and verdadero)
print("Resultado de la combinación de operadores lógicos:", resultado_combinado)
# Out:
# Resultado de la combinación de operadores lógicos: True

# %% [markdown]
# Ejercicio 16: Verifica si un número es mayor que 100

# %%
# Definir el número
numero = 120

#Verificar si es mayor que 100 sin condicionales
resultado_mayor = numero > 100
print("¿El número es mayor que 100?", resultado_mayor)
# Out:
# ¿El número es mayor que 100? True

# %% [markdown]
# # **HACER SIN USAR IF**

# %% [markdown]
# **Ejercicio 1: Determina si un número es divisible por 3 y por 5 💡** / TAREA

# %%
numero = int(input("Ingresa un numero: "))

resultado = {
    True: "Es divisible por 3 y 5",
    False: "No es divisible por 3 y 5 a la vez"
}

print(resultado[numero % 15 == 0])
# Out:
# Ingresa un numero: 5
# No es divisible por 3 y 5 a la vez

# %% [markdown]
# **Ejercicio 2: Calcula el residuo de la división de un número por 7 y verifica si es igual a 3 💡**

# %%
numero = int(input("Ingresa un numero: "))

residuo = numero % 7
es_igual_a_3 = (residuo == 3)

print("Residuo:", residuo)
print("¿El residuo es igual a 3?:", es_igual_a_3)
# Out:
# Ingresa un numero: 89
# Residuo: 5
# ¿El residuo es igual a 3?: False

# %% [markdown]
# **Ejercicio 3: Eleva un número al cuadrado, suma 10 y verifica si el resultado es mayor que 50  💡**

# %%
numero  = int (input("Ingresa un numero: "))

resultado = (numero ** 2 + 10) > 50

print (resultado)
# Out:
# Ingresa un numero: 9
# True

# %%
numero = int(input("Ingresa un numero: "))
calculo = (numero ** 2 + 10)
resultado = calculo > 50

print( "El N° es mayor a 50 ", resultado)
# Out:
# Ingresa un numero: 9
# El N° es mayor a 50  True

# %% [markdown]
# **Ejercicio 4: 📊 Calcula el producto de dos números y verifica si el resultado es menor que 20**

# %%
numero_1= int(input("Ingrese el primer numero "))
numero_2= int(input("Ingrese el segundo numero "))

calculo = ( numero_1 * numero_2 ) < 20

print (" El N° es menor a 20 =", calculo)
# Out:
# Ingrese el primer numero 9
# Ingrese el segundo numero 6
#  El N° es menor a 20 = False

# %% [markdown]
# **Ejercicio 5: 🎲 Calcula el área de un círculo con radio 5 y verifica si es mayor que 50.**

# %%
pi = 3.1416
r = 5

area =( pi * r **2 ) > 50

print("el area es mayor a 50", area)
# Out:
# el area es mayor a 50 True
