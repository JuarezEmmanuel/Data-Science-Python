# %% [markdown]
# <a href="https://colab.research.google.com/github/JuarezEmmanuel/Data-Science-Python/blob/main/practica_0_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 1.01 Pidan el ingreso de un dato por teclado y guárdenlo en una variable a Muestren por pantalla el contenido de a

# %%
a = input("Ingrese un dato: ")
print(a)
# Out:
# Ingrese un dato: 4
# 4

# %% [markdown]
# - 1.02 Pidan el ingreso de un dato por teclado y guárdenlo en una variable a Convierta el dato a en un entero usando la función int Muestren por pantalla el contenido de a

# %%
a = input("Ingrese un dato: ")
a = int(a)
print(a)
# Out:
# Ingrese un dato: 5
# 5

# %% [markdown]
# - 1.03 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a+b

# %%
a = int(input("ingrese el valor de A:"))
b= int(input("Ingrese el valor de B:"))

c = a + b
print(c)
# Out:
# ingrese el valor de A:10
# Ingrese el valor de B:15
# 25

# %% [markdown]
# - 1.04 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a-b

# %%
a = int(input("Ingrese el valor de A ="))
b = int(input("Ingrese el valor de B ="))

print("El valor de A=",a)
print("El valor de B=",b)
# Out:
# Ingrese el valor de A =5
# Ingrese el valor de B =6
# El valor de A= 5
# El valor de B= 6

# %% [markdown]
# - 1.05 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a*b

# %%
a = int(input("Ingrese el valor de A ="))
b = int(input("Ingrese el valor de B ="))

c = a*b
print("El resultado es =",c)
# Out:
# Ingrese el valor de A =5
# Ingrese el valor de B =6
# El resultado es = 30

# %% [markdown]
# - 1.06 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a/b

# %%
a = int(input("Ingrese el valor de A ="))
b = int(input("Ingrese el valor de B ="))

print("El resultado es =",a / b
      )
# Out:
# Ingrese el valor de A =10
# Ingrese el valor de B =5
# El resultado es = 2.0

# %% [markdown]
# - 1.07 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a**b (potenciación)

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a ** b )
# Out:
# Ingrese al valor de A=5
# Ingrese el valor de B=6
# 15625

# %% [markdown]
# - 1.08 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a//b *texto en cursiva*

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a // b )
# Out:
# Ingrese al valor de A=5
# Ingrese el valor de B=5
# 1

# %% [markdown]
# - 1.09 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a%b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a % b )
# Out:
# Ingrese al valor de A=10
# Ingrese el valor de B=8
# 2

# %% [markdown]
# - 1.10 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a==b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a == b )
# Out:
# Ingrese al valor de A=10
# Ingrese el valor de B=8
# False

# %% [markdown]
# - 1.11 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a!=b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a != b )
# Out:
# Ingrese al valor de A=5
# Ingrese el valor de B=6
# True

# %% [markdown]
# - 1.12 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a<b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a < b )
# Out:
# Ingrese al valor de A=5
# Ingrese el valor de B=6
# True

# %% [markdown]
# - 1.13 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a<=b *texto en cursiva*

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a <= b )
# Out:
# Ingrese al valor de A=1
# Ingrese el valor de B=1
# True

# %% [markdown]
# - 1.14 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a>b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a > b )
# Out:
# Ingrese al valor de A=8
# Ingrese el valor de B=5
# True

# %% [markdown]
# - 1.15 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a>=b

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))

print( a >= b )
# Out:
# Ingrese al valor de A=10
# Ingrese el valor de B=10
# True

# %% [markdown]
# - 1.16 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b AND c==d

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))
c = int(input("Ingrese al valor de C="))
d = int(input("Ingrese el valor de D="))

print( a == b and c == d )
# Out:
# Ingrese al valor de A=5
# Ingrese el valor de B=8
# Ingrese al valor de C=5
# Ingrese el valor de D=6
# False

# %% [markdown]
# - 1.17 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b OR c==d

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))
c = int(input("Ingrese al valor de C="))
d = int(input("Ingrese el valor de D="))

print( a == b or c == d )
# Out:
# Ingrese al valor de A=2
# Ingrese el valor de B=2
# Ingrese al valor de C=2
# Ingrese el valor de D=2
# True

# %% [markdown]
# - 1.18 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b OR NOT c==d

# %%
a = int(input("Ingrese al valor de A="))
b = int(input("Ingrese el valor de B="))
c = int(input("Ingrese al valor de C="))
d = int(input("Ingrese el valor de D="))

print( a == b or not c == d )

# %% [markdown]
# - 1.19 Pidan el ingreso de un dato a por teclado. Guarde en b el valor como flotante Guarde en c el valor de a como string Muestre por pantalla el contenido de a, b y c Muestra por pantalla los tipos de a, b y c *texto en cursiva*

# %%
a = input("Ingrese valor a: ")

b = float(a)
c = str(a)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# Ingrese valor a: 8
# 8
# 8.0
# 8
# <class 'str'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# - 1.20 Crear una lista con los días hábiles de la semana Agregar a la lista el sábado y el domingo Mostrar el contenido de la lista

# %%
l = ["Lunes","Martes","Miércoles","Jueves","Viernes"]

l.append("Sábado")
l.append("Domingo")

print(l)
# Out:
# ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# %% [markdown]
# - 1.21 Crear una lista con los días de la semana Eliminar de la lista el sábado y el domingo Mostrar el contenido de la lista

# %%
l = ["Lunes","Martes","Miércoles","Jueves","Viernes","Sábado","Domingo"]

l.remove("Sábado")
l.remove("Domingo")

print(l)
# Out:
# ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes']

# %% [markdown]
# - 1.22 Crear una lista l1 con todos los días de la semana Imprimir la longitud de l1 Extender l1 con si misma Imprimir la longitud de l1

# %%
l1 = ["lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo"]

print(len(l1))   # 7

l1.extend(l1)

print(len(l1))   # 14
# Out:
# 7
# 14

# %% [markdown]
# - 1.23 Crear una lista con los días hábiles de la semana y otra lista con el sábado y el domingo Extender la primera lista con la segunda Mostrar el contenido de la lista

# %%
dias_habiles = ["lunes", "martes", "miércoles", "jueves", "viernes"]
fin_de_semana = ["sábado", "domingo"]

dias_habiles.extend(fin_de_semana)

print(dias_habiles)
# Out:
# ['lunes', 'martes', 'miércoles', 'jueves', 'viernes', 'sábado', 'domingo']

# %% [markdown]
# - 1.24 Crear una tupla t1 con todos los días de la semana Mostrar por pantalla el número de elemento correspondiente al miércoles

# %%
t1 = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

print(t1.index("miércoles"))
# Out:
# 2

# %% [markdown]
# - Tarea 1.25 Crear una tupla t1 con todos los días de la semana Imprimir la longitud de t1

# %%
t1 = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

print(len(t1))
# Out:
# 7

# %% [markdown]
# - 1.26 Crear una tupla t1 con todos los días de la semana Averiguar si domingo se encuentra entre todos los días de la semana

# %%
t1 = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

print("domingo" in t1)
# Out:
# True

# %% [markdown]
# 1.27 Crear una tupla t1 con todos los días de la semana Crear una lista l1 a partir de t1

# %%
t1 = ("lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo")

l1 = list(t1)

print(l1)
# Out:
# ['lunes', 'martes', 'miércoles', 'jueves', 'viernes', 'sábado', 'domingo']

# %% [markdown]
# - Tarea 1.28 Crear una lista l1 con todos los días de la semana Crear una tupla t1 a partir de l1

# %%
l1 = ["lunes", "martes", "miércoles", "jueves", "viernes", "sábado", "domingo"]

t1 = tuple(l1)

print(l1)
# Out:
# ['lunes', 'martes', 'miércoles', 'jueves', 'viernes', 'sábado', 'domingo']

# %% [markdown]
# - Tarea 1.29 Pidan el ingreso de dos datos a por teclado. Convierta los datos a flotantes Si el primer dato es mayor que el segundo muestre por pantalla el cartel: mayor

# %% [markdown]
# - Tarea 1.30 Pidan el ingreso de dos datos a por teclado. Convierta los datos a flotantes Muestre por pantalla los datos ordenados de menor a mayor

# %% [markdown]
# - Tarea 1.31 Ingresar por teclado una edad. Devolver por pantalla un mensaje proporcionado a la edad: Menor a 15: edad de crecer De 15 a 40: edad del amor De 40 a 65: edad de los amigos De 65 en adelante: edad de los médicos

# %% [markdown]
# - Tarea 1.32 Ingresar por teclado una edad. Mostrar por pantalla todos los cumples que la persona tuvo hasta ahora: Cumpleaños 1 Cumpleaños2 …

# %% [markdown]
# - Tarea 1.33 Crear una lista l1 con todos los días de la semana Crear una lista l2 con los días hábiles de la semana Recorrer l1 e indicar para cada elemento si se encuentra o no en l2

# %% [markdown]
# - Tarea 1.34 Generar una lista l1 con los números del 1 al 10 Generar una lista l2 que tenga una lista con los números del uno al 10 en cada uno de sus 10 elementos Recorrer l2 con un for anidado dentro de otro para mostrar todos los elementos y su posición (ubicación en la lista, y dentro de la sub lista)

# %% [markdown]
# - Tarea 1.35 Crear una lista l1 con todos los impares de 1 a 5  (usar for) Insertar los pares en los lugares correspondientes para que la lista quede ordenada, de la forma que considere mejor. Imprimir l1

# %% [markdown]
# - Tarea 1.36 Crear una lista l1 con todos los días de la semana Recorrer l1 imprimiendo elemento por elemento

# %% [markdown]
# - Tarea 1.37 Crear una lista con los días de la semana Mostrar el contenido de la lista con un único print Mostrar el contenido de la lista elemento por elemento

# %% [markdown]
# - Tarea 1.38 Crear una diccionario d con todos los días de la semana poniendo como clave las siete primeras letras del alfabeto Imprimir el diccionario

# %% [markdown]
# - Tarea 1.39 Tomar el diccionario generado en el ejercicio 1.38 y cambiar cada valor a letras mayúsculas Imprimir el resultado

# %% [markdown]
# - Tarea 1.40 Crear una tupla con la siete primeras letras del alfabeto Recorrer la tupla y usarla como clave para imprimir los valores del diccionario construido en la tarea 1.38

# %% [markdown]
# -  Tarea 1.41 Tomar el diccionario del ejercicio 1.38 Imprimir su colección de claves

# %% [markdown]
# - Tarea 1.42 Tomar el diccionario del ejercicio 1.38 Imprimir su colección de valores

# %% [markdown]
# - Tarea 1.43 Tomar el diccionario del ejercicio 1.38 Imprimir su longitud

# %% [markdown]
# - Tarea 1.44 Generar para cada provincia una tupla con el nombre de la provincia, su capital, su población y su PBI. Armar un diccionario donde cada valor sea la tupla de una provincia y la claves sea el nombre de la provincia. Mostrar para cada provincia su capital.

# %% [markdown]
# - Tarea 1.45 A partir del programa anterior recorrer las letras de las tres primeras ciudades de la lista y mostrar cada letra por pantalla en un nuevo renglón.

# %% [markdown]
# - Tarea 1.46 Crear una tupla con los siete días de la semana Recorrer los 365 días del año actual Para cada día del año imprimir el nombre del día de la semana

# %% [markdown]
# - Tarea 1.47 Crear una tupla con las longitudes de los meses del año actual Recorrer el año mostrando por pantalla el número de día dentro del año y el número del día dentro del mes.

# %% [markdown]
# - Tarea 1.48 Crear una tupla t1 con las longitudes de los meses del año actual Crear una tupla t2 con los nombres de los meses del año Recorrer el año mostrando por pantalla el número de día dentro del año y el número del día dentro del mes y el nombre del mes

# %% [markdown]
# - Tarea 1.49 Crear una tupla t1 con las longitudes de los meses del año actual Crear una tupla t2 con los nombres de los meses del año Crear una tupla t3 con los nombres de los días de la semana Recorrer el año mostrando por pantalla el número de día dentro del año y el nombre del día dentro de la semana, el número del día dentro del mes.y el nombre del mes

# %% [markdown]
# - Tarea 1.50 Basado en el ejercicio 1.49, crear una lista con las fechas mostradas anteriormente (día del año, nombre del día dentro de la semana, número del día dentro del mes, nombre del mes)

# %% [markdown]
# - Tarea 1.51 Pedir la introducción desde el teclado de una fecha en el formato largo. Usar la lista generada en el ejercicio 1.50 para encontrar el número de día dentro del año.

# %% [markdown]
# - Tarea 1.52 Ingresar por teclado dos enteros en a y b. Crear una función de dos parámetros que devuelve la suma de esos parámetros Usar la función creada para calcular la suma de a y b. Mostrar por pantalla el resultado de la suma

# %% [markdown]
# - Tarea 1.53 Desarrollar una función que obligue a ingresar un número entero y no continúe la ejecución hasta que no se ingresa un entero: (Sugerencia: usar try, tomar float, y si no da error verificar que el numero ingresado es igual a int(número ingresado) Proveer realimentación para guiar al usuario

# %% [markdown]
# - Tarea 1.54 Construya un generador que vaya recorriendo la sucesión aritmética: 1, 2, 3, 4, 5 … Imprima por pantalla los 10 primeros valores

# %% [markdown]
# - Tarea 1.55 Construya un generador que vaya recorriendo la serie que va sumando la sucesión aritmética: 1, 3, 6, 10, 15, 21 … Imprima por pantalla los 10 primeros valores

# %% [markdown]
# - Tarea 1.56 Construya un generador que vaya recorriendo la serie geométrica: 1, 2, 4, 8, 16, 32, 64 … Imprima por pantalla los 10 primeros valores

# %% [markdown]
# - Tarea 1.57 Construya un generador que vaya recorriendo la suma de la serie geométrica: 1, 3, 7, 15, 31, 63, 127 Imprima por pantalla los 10 primeros valores

# %% [markdown]
# - Tarea 1.58 Investigar cuales son las excepciones para: - Sumar un número y un string- Tomar int de un string que no es un número - Tomar float de un string que no es un número

# %% [markdown]
# - Tarea 1.59 Investigue las excepciones que puede causar con sqrt, log, pow

# %% [markdown]
# Tarea 1.01 Pidan el ingreso de un dato por teclado y guárdenlo en una variable a Muestren por pantalla el contenido de a
#
#
# Tarea 1.02 Pidan el ingreso de un dato por teclado y guárdenlo en una variable a Convierta el dato a en un entero usando la función int Muestren por pantalla el contenido de a
#
#
# Tarea 1.03 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a+b
#
#
# Tarea 1.04 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a-b
#
#
# Tarea 1.05 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a*b
#
#
# Tarea 1.06 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a/b
#
#
# Tarea 1.07 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a**b (potenciación)
#
#
# Tarea 1.08 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a//b
#
#
# Tarea 1.09 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a%b
#
#
# Tarea 1.10 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a==b
#
#
# Tarea 1.11 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a!=b
#
#
# Tarea 1.12 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a<b
#
#
# Tarea 1.13 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a<=b
#
#
# Tarea 1.14 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a>b
#
#
# Tarea 1.15 Pidan el ingreso de dos datos a y b por teclado. Convierta a y b a enteros usando la función int Muestren por pantalla el contenido de a>=b
#
#
# Tarea 1.16 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b AND c==d
#
#
# Tarea 1.17 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b OR c==d
#
#
# Tarea 1.18 Pidan el ingreso de cuatro datos a,b,c y d por teclado. Convierta a, b, c y d a enteros usando la función int Muestren por pantalla el contenido de a==b OR NOT c==d
#
# Tarea 1.19 Pidan el ingreso de un dato a por teclado. Guarde en b el valor como flotante Guarde en c el valor de a como string Muestre por pantalla el contenido de a, b y c Muestra por pantalla los tipos de a, b y c
#
#
# Tarea 1.20 Crear una lista con los días hábiles de la semana Agregar a la lista el sábado y el domingo Mostrar el contenido de la lista
#
#
# Tarea 1.21 Crear una lista con los días de la semana Eliminar de la lista el sábado y el domingo Mostrar el contenido de la lista
#
#
# Tarea 1.22 Crear una lista l1 con todos los días de la semana Imprimir la longitud de l1 Extender l1 con si misma Imprimir la longitud de l1
#
#
# Tarea 1.23 Crear una lista con los días hábiles de la semana y otra lista con el sábado y el domingo Extender la primera lista con la segunda Mostrar el contenido de la lista
#
#
# Tarea 1.24 Crear una tupla t1 con todos los días de la semana Mostrar por pantalla el número de elemento correspondiente al miércoles
#
# Tarea 1.25 Crear una tupla t1 con todos los días de la semana Imprimir la longitud de t1
#
#
# Tarea 1.26 Crear una tupla t1 con todos los días de la semana Averiguar si domingo se encuentra entre todos los días de la semana
#
#
# Tarea 1.27 Crear una tupla t1 con todos los días de la semana Crear una lista l1 a partir de t1
#
#
# Tarea 1.28 Crear una lista l1 con todos los días de la semana Crear una tupla t1 a partir de l1
#
#
# Tarea 1.29 Pidan el ingreso de dos datos a por teclado. Convierta los datos a flotantes Si el primer dato es mayor que el segundo muestre por pantalla el cartel: mayor
#
#
# Tarea 1.30 Pidan el ingreso de dos datos a por teclado. Convierta los datos a flotantes Muestre por pantalla los datos ordenados de menor a mayor
#
#
# Tarea 1.31 Ingresar por teclado una edad. Devolver por pantalla un mensaje proporcionado a la edad: Menor a 15: edad de crecer De 15 a 40: edad del amor De 40 a 65: edad de los amigos De 65 en adelante: edad de los médicos
#
#
# Tarea 1.32 Ingresar por teclado una edad. Mostrar por pantalla todos los cumples que la persona tuvo hasta ahora: Cumpleaños 1 Cumpleaños2 …
#
#
# Tarea 1.33 Crear una lista l1 con todos los días de la semana Crear una lista l2 con los días hábiles de la semana Recorrer l1 e indicar para cada elemento si se encuentra o no en l2
#
#
# Tarea 1.34 Generar una lista l1 con los números del 1 al 10 Generar una lista l2 que tenga una lista con los números del uno al 10 en cada uno de sus 10 elementos Recorrer l2 con un for anidado dentro de otro para mostrar todos los elementos y su posición (ubicación en la lista, y dentro de la sub lista)
#
#
# Tarea 1.35 Crear una lista l1 con todos los impares de 1 a 5  (usar for) Insertar los pares en los lugares correspondientes para que la lista quede ordenada, de la forma que considere mejor. Imprimir l1
#
#
# Tarea 1.36 Crear una lista l1 con todos los días de la semana Recorrer l1 imprimiendo elemento por elemento
#
#
# Tarea 1.37 Crear una lista con los días de la semana Mostrar el contenido de la lista con un único print Mostrar el contenido de la lista elemento por elemento
#
#
# Tarea 1.38 Crear una diccionario d con todos los días de la semana poniendo como clave las siete primeras letras del alfabeto Imprimir el diccionario
#
#
# Tarea 1.39 Tomar el diccionario generado en el ejercicio 1.38 y cambiar cada valor a letras mayúsculas Imprimir el resultado
#
#
# Tarea 1.40 Crear una tupla con la siete primeras letras del alfabeto Recorrer la tupla y usarla como clave para imprimir los valores del diccionario construido en la tarea 1.38
#
#
#  Tarea 1.41 Tomar el diccionario del ejercicio 1.38 Imprimir su colección de claves
#
#
# Tarea 1.42 Tomar el diccionario del ejercicio 1.38 Imprimir su colección de valores
#
# Tarea 1.43 Tomar el diccionario del ejercicio 1.38 Imprimir su longitud
#
#
# Tarea 1.44 Generar para cada provincia una tupla con el nombre de la provincia, su capital, su población y su PBI. Armar un diccionario donde cada valor sea la tupla de una provincia y la claves sea el nombre de la provincia. Mostrar para cada provincia su capital.
#
#
# Tarea 1.45 A partir del programa anterior recorrer las letras de las tres primeras ciudades de la lista y mostrar cada letra por pantalla en un nuevo renglón.
#
# Tarea 1.46 Crear una tupla con los siete días de la semana Recorrer los 365 días del año actual Para cada día del año imprimir el nombre del día de la semana
#
#
# Tarea 1.47 Crear una tupla con las longitudes de los meses del año actual Recorrer el año mostrando por pantalla el número de día dentro del año y el número del día dentro del mes.
#
#
# Tarea 1.48 Crear una tupla t1 con las longitudes de los meses del año actual Crear una tupla t2 con los nombres de los meses del año Recorrer el año mostrando por pantalla el número de día dentro del año y el número del día dentro del mes y el nombre del mes
#
#
# Tarea 1.49 Crear una tupla t1 con las longitudes de los meses del año actual Crear una tupla t2 con los nombres de los meses del año Crear una tupla t3 con los nombres de los días de la semana Recorrer el año mostrando por pantalla el número de día dentro del año y el nombre del día dentro de la semana, el número del día dentro del mes.y el nombre del mes
#
#
# Tarea 1.50 Basado en el ejercicio 1.49, crear una lista con las fechas mostradas anteriormente (día del año, nombre del día dentro de la semana, número del día dentro del mes, nombre del mes)
#
#
# Tarea 1.51 Pedir la introducción desde el teclado de una fecha en el formato largo. Usar la lista generada en el ejercicio 1.50 para encontrar el número de día dentro del año.
#
#
# Tarea 1.52 Ingresar por teclado dos enteros en a y b. Crear una función de dos parámetros que devuelve la suma de esos parámetros Usar la función creada para calcular la suma de a y b. Mostrar por pantalla el resultado de la suma
#
#
# Tarea 1.53 Desarrollar una función que obligue a ingresar un número entero y no continúe la ejecución hasta que no se ingresa un entero: (Sugerencia: usar try, tomar float, y si no da error verificar que el numero ingresado es igual a int(número ingresado) Proveer realimentación para guiar al usuario
#
#
# Tarea 1.54 Construya un generador que vaya recorriendo la sucesión aritmética: 1, 2, 3, 4, 5 … Imprima por pantalla los 10 primeros valores
#
# Tarea 1.55 Construya un generador que vaya recorriendo la serie que va sumando la sucesión aritmética: 1, 3, 6, 10, 15, 21 … Imprima por pantalla los 10 primeros valores
#
# Tarea 1.56 Construya un generador que vaya recorriendo la serie geométrica: 1, 2, 4, 8, 16, 32, 64 … Imprima por pantalla los 10 primeros valores
#
# Tarea 1.57 Construya un generador que vaya recorriendo la suma de la serie geométrica: 1, 3, 7, 15, 31, 63, 127 Imprima por pantalla los 10 primeros valores
#
# Tarea 1.58 Investigar cuales son las excepciones para: - Sumar un número y un string- Tomar int de un string que no es un número - Tomar float de un string que no es un número
#
# Tarea 1.59 Investigue las excepciones que puede causar con sqrt, log, pow.
